python3.13/json/decoder.py": 1778015152.0, "/usr/lib/python3.13/json/encoder.py": 1778015152.0, "/usr/lib/python3.13/json/__init__.py": 1778015152.0, "/usr/lib/python3.13/locale.py": 1778015152.0, "/usr/lib/python3.13/signal.py": 1778015152.0, "/usr/lib/python3.13/_weakrefset.py": 1778015152.0, "/usr/lib/python3.13/threading.py": 1778015152.0, "/usr/lib/python3.13/selectors.py": 1778015152.0, "/usr/lib/python3.13/subprocess.py": 1778015152.0, "/usr/lib/python3.13/typing.py": 1778015152.0, "/home/omarlizardo/CULTURE PROJECTS/OMAR PROJECTS/lizardo-folk-models-of-good-and-bad-taste/.venv/lib/python3.13/site-packages/jupyter_client/_version.py": 1784256050.151167, "/usr/lib/python3.13/platform.py": 1778015152.0, "/home/omarlizardo/CULTURE PROJECTS/OMAR PROJECTS/lizardo-folk-models-of-good-and-bad-taste/.venv/lib/python3.13/site-packages/zmq/backend/select.py": 1784256034.0164018, "/usr/lib/python3.13/ast.py": 1778015152.0, "/usr/lib/python3.13/_opcode_metadata.py": 1778015152.0, "/usr/lib/python3.13/opcode.py": 1778015152.0, "/usr/lib/python3.13/dis.py": 1778015152.0, "/usr/lib/python3.13/linecache.py": 1778015152.0, "/usr/lib/python3.13/token.py": 1778015152.0, "/usr/lib/python3.13/tokenize.py": 1778015152.0, "/usr/lib/python3.13/weakref ...

# %%
#| label: load-packages
import pandas as pd
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# %%
#| label: load-data
df = pd.read_csv("data/FolkTaste_CleanData.csv")

# The questionnaire skip pattern dictates that only people who answered YES to Taste_Possibility
# provided definitions for GoodTaste_Def and BadTaste_Def.
df_filtered = df[df['Taste_Possibility'] == 'YES'].copy()

# Extract the "GoodTaste_Def" and "BadTaste_Def" columns and drop empty responses
good_taste_docs = df_filtered["GoodTaste_Def"].dropna().astype(str).tolist()
bad_taste_docs = df_filtered["BadTaste_Def"].dropna().astype(str).tolist()

# %%
#| label: load-good-taste
good_topic_model = BERTopic.load("good_taste_model")
good_topic_model.get_topic_info().head(10)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
#    Topic  Count                          Name  \
# 0     -1     36  -1_good_taste_person_usually
# 1      0     95  0_things_like_art_appreciate
# 2      1     88         1_taste_good_say_like
# 3      2     41     2_good_taste_person_think
# 4      3     18       3_means_like_good_knows
#
#                                       Representation  Representative_Docs
# 0  [good, taste, person, usually, think, means, j...                  NaN
# 1  [things, like, art, appreciate, good, choices,...                  NaN
# 2  [taste, good, say, like, person, think, means,...                  NaN
# 3  [good, taste, person, think, things, people, s...                  NaN
# 4  [means, like, good, knows, choices, interact, ...                  NaN

# %%
#| label: visualize-good-taste-distance
good_topic_model.visualize_topics()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.7.0.min"</script>
# <div style="height:650px; width:650px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="d893a514-59fe-43d9-a723-be2198deb846" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d893a514-59fe-43d9-a723-be2198deb846")) {                    Plotly.newPlot(                        "d893a514-59fe-43d9-a723-be2198deb846",                        [{"customdata":[[0,"things | like | art | appreciate | good",95],[1,"taste | good | say | like | person",88],[2,"good | taste | person | think | things",41],[3,"means | like | good | knows | choices",18]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":{"dtype":"i1","bdata":"X1gpEg=="},"sizemode":"area","sizeref":0.059375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f4","bdata":"mwF4wG7mH8B2ylLARU53wA=="},"xaxis":"x","y":{"dtype":"f4","bdata":"zl1yQSXDe0FhvH9BGRJlQQ=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d": ...

# %%
#| label: visualize-good-taste-barchart
good_topic_model.visualize_barchart(top_n_topics=8)
# Out:
# <div style="height:325.0px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="590900e3-a27e-40ce-a2eb-479feefdd6ca" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("590900e3-a27e-40ce-a2eb-479feefdd6ca")) {                    Plotly.newPlot(                        "590900e3-a27e-40ce-a2eb-479feefdd6ca",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.05510052106036486,0.05551904468934567,0.0620789447460321,0.08411389694905831,0.0916873091497051],"y":["good  ","appreciate  ","art  ","like  ","things  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.05231494369585517,0.0542458454715195,0.05625462969992683,0.12023068100140431,0.13742334138975115],"y":["person  ","like  ","say  ","good  ","taste  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.05725699676894045,0.05905453841065089,0.06416655351825552,0.0946435773867185,0.09917956565593236],"y":["things  ","think  ","person  ","taste  ","good  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.07100251044736948,0.07292969240098589,0.07548600795421502,0.13269304598915618,0.2352110413746215],"y":["choices  ","knows  ","good  ","like  ","means  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity ...

# %%
#| label: visualize-good-taste-hierarchy
good_topic_model.visualize_hierarchy()
# Out:
# <div style="height:260px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="88602130-d0f6-442b-89de-a09a70c939ca" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("88602130-d0f6-442b-89de-a09a70c939ca")) {                    Plotly.newPlot(                        "88602130-d0f6-442b-89de-a09a70c939ca",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"AAAAAAAAAAC2zVMzjq\u002fXP7bNUzOOr9c\u002fAAAAAAAAAAA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAALsAAAAAAAAAuwAAAAAAAADnAAAAAAAAAOcA="},"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"ts1TM46v1z8QeDj0kf3fPxB4OPSR\u002fd8\u002fAAAAAAAAAAA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAANMAAAAAAAAA0wAAAAAAAgEHAAAAAAACAQcA="},"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"AAAAAAAAAABgUEOE4tflP2BQQ4Ti1+U\u002fEHg49JH93z8="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAFMAAAAAAAAAUwAAAAAAAgDvAAAAAAACAO8A="},"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":260,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["3_means_like_good","1_taste_good_say","2_good_taste_person","0_things_like_art"],"tickvals":[-5.0,-15.0,-25.0,-35.0],"type":"linear","zeroline":false,"range":[-40.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorsc ...

# %%
#| label: load-bad-taste
bad_topic_model = BERTopic.load("bad_taste_model")
bad_topic_model.get_topic_info().head(10)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
#    Topic  Count                          Name  \
# 0     -1     76      -1_taste_bad_like_things
# 1      0     95     0_taste_bad_person_things
# 2      1     44       1_like_things_just_care
# 3      2     25   2_person_people_things_loud
# 4      3     16          3_art_dont_taste_bad
# 5      4     11  4_means_usually_like_quality
# 6      5     11     5_music_shows_enjoying_tv
#
#                                       Representation  Representative_Docs
# 0  [taste, bad, like, things, dont, person, choic...                  NaN
# 1  [taste, bad, person, things, people, say, thin...                  NaN
# 2  [like, things, just, care, maybe, people, plai...                  NaN
# 3  [person, people, things, loud, likes, colors, ...                  NaN
# 4  [art, dont, taste, bad, like, opinions, person...                  NaN
# 5  [means, usually, like, quality, acceptable, ra...                  NaN
# 6  [music, shows, enjoying, tv, enjoy, movies, ba...                  NaN

# %%
#| label: visualize-bad-taste-distance
bad_topic_model.visualize_topics()
# Out:
# <div style="height:650px; width:650px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="24d413fe-ca30-406a-8f03-81bc243936df" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("24d413fe-ca30-406a-8f03-81bc243936df")) {                    Plotly.newPlot(                        "24d413fe-ca30-406a-8f03-81bc243936df",                        [{"customdata":[[0,"taste | bad | person | things | people",95],[1,"like | things | just | care | maybe",44],[2,"person | people | things | loud | likes",25],[3,"art | dont | taste | bad | like",16],[4,"means | usually | like | quality | acceptable",11],[5,"music | shows | enjoying | tv | enjoy",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":{"dtype":"i1","bdata":"XywZEAsL"},"sizemode":"area","sizeref":0.059375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f4","bdata":"\u002fFfUwPcpBMH5or\u002fAyyHhwDZUzsCFM\u002ffA"},"xaxis":"x","y":{"dtype":"f4","bdata":"ITyYP2vXYz7ktRdAp+3HPkAP\u002fD86saK9"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"] ...

# %%
#| label: visualize-bad-taste-barchart
bad_topic_model.visualize_barchart(top_n_topics=8)
# Out:
# <div style="height:500px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="870c8902-0c7a-4d9f-8a8e-9af7ae122030" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("870c8902-0c7a-4d9f-8a8e-9af7ae122030")) {                    Plotly.newPlot(                        "870c8902-0c7a-4d9f-8a8e-9af7ae122030",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03570639990727824,0.036301501830646864,0.044876326142390684,0.10756346590004429,0.10778979665931628],"y":["people  ","things  ","person  ","bad  ","taste  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.05455542489854612,0.06260868841917716,0.08516647497717611,0.11000479261090156,0.13772992334744746],"y":["maybe  ","care  ","just  ","things  ","like  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.05006366554951423,0.05537845932589487,0.057900032126140234,0.0615493752524635,0.08087234479970798],"y":["likes  ","loud  ","things  ","people  ","person  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.05223091296026389,0.059485856141691155,0.06604386821691921,0.06764095211222568,0.11636059064362436],"y":["like  ","bad  ","taste  ","dont  ","art  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.08536629802386049,0.08683795108104454,0.09401564332847501,0.09572265416280042,0.21081806899064384],"y":["acceptable  ","quality  ","like  ","usually  ","means  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.06589651898420658,0.07177543331624363,0.07734838855041218,0.12077651181586278,0.12557873311848944],"y":["enjoy  ","tv  ","enjoying  ","shows  ","music  "],"type":"bar","xaxis":"x6","yaxis":"y6"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888888 ...

# %%
#| label: visualize-bad-taste-hierarchy
bad_topic_model.visualize_hierarchy()
# Out:
# <div style="height:290px; width:1000px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="25e3ad03-b045-437e-9a19-1812bd1365f1" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("25e3ad03-b045-437e-9a19-1812bd1365f1")) {                    Plotly.newPlot(                        "25e3ad03-b045-437e-9a19-1812bd1365f1",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"AAAAAAAAAABOzZ+WWh\u002foP07Nn5ZaH+g\u002fAAAAAAAAAAA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAALsAAAAAAAAAuwAAAAAAAADnAAAAAAAAAOcA="},"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"AAAAAAAAAAAYO\u002fA\u002fUBbiPxg78D9QFuI\u002fAAAAAAAAAAA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACAQcAAAAAAAIBBwAAAAAAAgEbAAAAAAACARsA="},"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"GDvwP1AW4j\u002fvzzrPnXDmP+\u002fPOs+dcOY\u002fAAAAAAAAAAA="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAARMAAAAAAAABEwAAAAAAAgEvAAAAAAACAS8A="},"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"Ts2fllof6D8\u002f76xZpXrpPz\u002fvrFmleuk\u002f7886z51w5j8="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAANMAAAAAAAAA0wAAAAAAAwEfAAAAAAADAR8A="},"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":{"dtype":"f8","bdata":"AAAAAAAAAADZH+U8LuDrP9kf5Twu4Os\u002fP++sWaV66T8="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAFMAAAAAAAAAUwAAAAAAA4EDAAAAAAADgQMA="},"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":290,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["5_music_shows_enjoying","2_person_people_things","1_like_things_just","3_art_dont_taste","0_taste_bad_person","4_means_usually_like"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0],"type":"linear","zeroline":false,"range":[-60.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444," ...

# %%
#| label: export-results
# Export summary tables to HTML
good_info = good_topic_model.get_topic_info()
good_info.to_html("good_taste_summary_table.html", index=False)

bad_info = bad_topic_model.get_topic_info()
bad_info.to_html("bad_taste_summary_table.html", index=False)
